# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#sns.set_style=("darkgrid")
#import random 
#random_palette=sns.color_palette([random.random(),random

# %%
print(df.columns)
# Out:
# Index(['acousticness', 'danceability', 'duration_ms', 'energy',
#        'instrumentalness', 'key', 'liveness', 'loudness', 'mode',
#        'speechiness', 'tempo', 'time_signature', 'valence', 'target',
#        'song_title', 'artist'],
#       dtype='object')

# %%
df=pd.read_csv ('C:\\Users\\Sandra Kimiring\\OneDrive\\Desktop\\data.csv')

df.head()
# Out:
#    Unnamed: 0  acousticness  danceability  duration_ms  energy  \
# 0           0        0.0102         0.833       204600   0.434
# 1           1        0.1990         0.743       326933   0.359
# 2           2        0.0344         0.838       185707   0.412
# 3           3        0.6040         0.494       199413   0.338
# 4           4        0.1800         0.678       392893   0.561
#
#    instrumentalness  key  liveness  loudness  mode  speechiness    tempo  \
# 0          0.021900    2    0.1650    -8.795     1       0.4310  150.062
# 1          0.006110    1    0.1370   -10.401     1       0.0794  160.083
# 2          0.000234    2    0.1590    -7.148     1       0.2890   75.044
# 3          0.510000    5    0.0922   -15.236     1       0.0261   86.468
# 4          0.512000    5    0.4390   -11.648     0       0.0694  174.004
#
#    time_signature  valence  target      song_title            artist
# 0             4.0    0.286       1        Mask Off            Future
# ...

# %%
df.drop("Unnamed: 0", axis=1, inplace=True)

# %%
df.head()
# Out:
#    acousticness  danceability  duration_ms  energy  instrumentalness  key  \
# 0        0.0102         0.833       204600   0.434          0.021900    2
# 1        0.1990         0.743       326933   0.359          0.006110    1
# 2        0.0344         0.838       185707   0.412          0.000234    2
# 3        0.6040         0.494       199413   0.338          0.510000    5
# 4        0.1800         0.678       392893   0.561          0.512000    5
#
#    liveness  loudness  mode  speechiness    tempo  time_signature  valence  \
# 0    0.1650    -8.795     1       0.4310  150.062             4.0    0.286
# 1    0.1370   -10.401     1       0.0794  160.083             4.0    0.588
# 2    0.1590    -7.148     1       0.2890   75.044             4.0    0.173
# 3    0.0922   -15.236     1       0.0261   86.468             4.0    0.230
# 4    0.4390   -11.648     0       0.0694  174.004             4.0    0.904
#
#    target      song_title            artist
# ...

# %%
##data cleaning

# %%
df.isna().sum()
# Out:
# acousticness        0
# danceability        0
# duration_ms         0
# energy              0
# instrumentalness    0
# key                 0
# liveness            0
# loudness            0
# mode                0
# speechiness         0
# tempo               0
# time_signature      0
# valence             0
# target              0
# song_title          0
# artist              0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2017 entries, 0 to 2016
# Data columns (total 16 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   acousticness      2017 non-null   float64
#  1   danceability      2017 non-null   float64
#  2   duration_ms       2017 non-null   int64
#  3   energy            2017 non-null   float64
#  4   instrumentalness  2017 non-null   float64
#  5   key               2017 non-null   int64
#  6   liveness          2017 non-null   float64
#  7   loudness          2017 non-null   float64
#  8   mode              2017 non-null   int64
#  9   speechiness       2017 non-null   float64
#  10  tempo             2017 non-null   float64
#  11  time_signature    2017 non-null   float64
#  12  valence           2017 non-null   float64
#  13  target            2017 non-null   int64
#  14  song_title        2017 non-null   object
#  15  artist            2017 non-null   object
# ...

# %%
df.shape
# Out:
# (2017, 16)

# %%
len(df.columns)
# Out:
# 16

# %%
df.describe()
# Out:
#        acousticness  danceability   duration_ms       energy  \
# count   2017.000000   2017.000000  2.017000e+03  2017.000000
# mean       0.187590      0.618422  2.463062e+05     0.681577
# std        0.259989      0.161029  8.198181e+04     0.210273
# min        0.000003      0.122000  1.604200e+04     0.014800
# 25%        0.009630      0.514000  2.000150e+05     0.563000
# 50%        0.063300      0.631000  2.292610e+05     0.715000
# 75%        0.265000      0.738000  2.703330e+05     0.846000
# max        0.995000      0.984000  1.004627e+06     0.998000
#
#        instrumentalness          key     liveness     loudness         mode  \
# count       2017.000000  2017.000000  2017.000000  2017.000000  2017.000000
# mean           0.133286     5.342588     0.190844    -7.085624     0.612295
# std            0.273162     3.648240     0.155453     3.761684     0.487347
# min            0.000000     0.000000     0.018800   -33.097000     0.000000
# ...

# %% [markdown]
# DATA ANALYSIS
# Top 5 most popular artists

# %%
top_five_artists=df.groupby("artist"). count().sort_values(by="song_title",ascending=False)["song_title"][:5]
top_five_artists
# Out:
# artist
# Drake              16
# Rick Ross          13
# Disclosure         12
# Backstreet Boys    10
# WALK THE MOON      10
# Name: song_title, dtype: int64

# %%
spotify_palette = ["#1DB954", "#191414", "#1ED760"]

# %%
top_five_artists.plot.barh(color=spotify_palette)
plt.show()

# %%
top_five_loudest_tracks=df[["loudness","song_title"]].sort_values(by="loudness",ascending =True)[:5]
top_five_loudest_tracks
# Out:
#       loudness                                         song_title
# 1594   -33.097            Lyric Pieces, Book I Op. 12: I. Arietta
# 1596   -31.367            8 Fantasiestücke, Op.12 : 1. Des Abends
# 1598   -31.082  Piano Quartet in E flat, Op.47: 3. Andante can...
# 1531   -30.447          I Was So Young, and You Were So Beautiful
# 1549   -29.460                                            Eleanor

# %%
plt.figure(figsize=(12,7))
sns.barplot(x="loudness",y="song_title",data=top_five_loudest_tracks,palette='viridis')
plt.title("Top 5 loudes tracks")
plt.show()
# Out:
# C:\Users\Sandra Kimiring\AppData\Local\Temp\ipykernel_35088\1596802774.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x="loudness",y="song_title",data=top_five_loudest_tracks,palette='viridis')

# %%
top_five_artists_danceable_songs=df[["danceability","song_title","artist"]].sort_value(by="danceability",ascending=False)[:5]
top_five_artists_danceable_songs
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_35088\973312142.py in ?()
# ----> 1 top_five_artists_danceable_songs=df[["danceability","song_title","artist"]].sort_value(by="danceability",ascending=False)[:5]
#       2 top_five_artists_danceable_songs
#
# ~\Desktop\anaconda\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6295             and name not in self._accessors
#    6296             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'sort_value'

# %%
plt.figure(figsize=(12,7))
sns.barplot(x="danceability",y="artist",data=top_five_artists_danceable_songs, palette='viridis')
plt.title("artists with the most danceability song")
plt.show()
# Out:
# C:\Users\Sandra Kimiring\AppData\Local\Temp\ipykernel_35088\3018304245.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x="danceability",y="artist",data=top_five_artists_danceable_songs, palette='viridis')

# %%
#top instrumental tracks
top_ten_instrumental_tracks =df[["instrumentalness", "song_title", "artist"]].sort_values(by="instrumentalness", ascending=False)[:5]
top_ten_instrumental_tracks
# Out:
#       instrumentalness                            song_title  \
# 1313             0.976                       Senseless Order
# 271              0.968  So Destroyed (channeling Rage Peace)
# 1575             0.964             A Hundred Dreams from Now
# 1619             0.958                                 Raven
# 725              0.957                     Strandbar (disko)
#
#                   artist
# 1313  Signs of the Swarm
# 271          Prince Rama
# 1575          Ray Bryant
# 1619       John Dahlbäck
# 725           Todd Terje

# %%
plt.figure(figsize=(12,7))
plt.pie(x="instrumentalness",data=top_ten_instrumental_tracks,autopct='%11.2f%%', labels=top_ten_instrumental_tracks.song_title)
plt.show()

# %%
intrest_feature_cols=["tempo","loudness","acousticness","danceability","duration_ms","energy","instrumentalness","liveness","speechiness","valence"]

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Create subplots (rows, columns)
num_plots = len(intrest_feature_cols)
num_columns = 2 # You can adjust the number of columns for better layout
num_rows = (num_plots // num_columns) + (num_plots % num_columns > 0)

fig, axes = plt.subplots(num_rows, num_columns, figsize=(18, num_rows * 6))

# Flatten the axes array to make indexing easier
axes = axes.flatten()

# Plot each feature column
for i, feature_col in enumerate(intrest_feature_cols):
    pos_data = df[df["target"] == 1][feature_col]
    neg_data = df[df["target"] == 0][feature_col]
    
    sns.histplot(pos_data, bins=30, label="Positive", color="green", kde=True, ax=axes[i])
    sns.histplot(neg_data, bins=30, label="Negative", color="red", kde=True, ax=axes[i])
    
    axes[i].legend(loc="upper right")
    axes[i].set_title(f"Positive and Negative Histogram Plot for {feature_col}")

# Adjust the layout to prevent overlapping
plt.tight_layout()
plt.show()

# %%
top_ten_energetic_tracks =df[["energy", "song_title", "artist"]].sort_values(by="energy", ascending=False)[:10]
top_ten_energetic_tracks
# Out:
#       energy           song_title                    artist
# 1299   0.998        No Absolution         Thy Art Is Murder
# 1322   0.997           Pitchblack  Walking Dead On Broadway
# 1297   0.994    A Darkened Gospel      A Wake in Providence
# 1347   0.993           Unanswered           Suicide Silence
# 2015   0.992        First Contact                Twin Moons
# 1680   0.992             Paranoia         A Day To Remember
# 1332   0.992      Beautiful Agony          Within The Ruins
# 1328   0.991  Down into the Abyss               Conjonctive
# 1681   0.990                Hated                 Beartooth
# 1296   0.990         Black Colors       Victim Of Deception

# %%
plt.figure(figsize=(12,7))
sns.barplot(x="energy",y="song_title",data=top_ten_energetic_tracks, palette='viridis')
plt.title("artists with the most energetic song")
plt.show()
# Out:
# C:\Users\Sandra Kimiring\AppData\Local\Temp\ipykernel_35088\1861183602.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x="energy",y="song_title",data=top_ten_energetic_tracks, palette='viridis')

# %%
top_ten_energetic_tracks =df[["energy", "song_title", "artist"]].sort_values(by="energy", ascending=False)[:10]
top_ten_energetic_tracks

# %%
most_popular_artist = df['artist'].value_counts().head(5)
print("Most Popular Artist:")
print(most_popular_artist)
# Out:
# Most Popular Artist:
# artist
# Drake              16
# Rick Ross          13
# Disclosure         12
# WALK THE MOON      10
# Backstreet Boys    10
# Name: count, dtype: int64

# %%
plt.figure(figsize=(12,7))
sns.barplot(x=most_popular_artist.values, y=most_popular_artist.index, palette='viridis')  # Use values for x and index for y
plt.title("Top 10 Popular Artists")

plt.show()
# Out:
# C:\Users\Sandra Kimiring\AppData\Local\Temp\ipykernel_35088\3519482503.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=most_popular_artist.values, y=most_popular_artist.index, palette='viridis')  # Use values for x and index for y

# %%
top_ten_valence_tracks = df[['valence', 'song_title', 'artist']].sort_values(by='valence', ascending=False).head(10)
top_ten_valence_tracks
# Out:
#       valence                                         song_title  \
# 460     0.992                             Abataka - Original Mix
# 912     0.975                I'm Walkin' - 2002 Digital Remaster
# 1966    0.974        To Roz Bikini (Itsy, Bitsy, Teenie, Weenie)
# 207     0.973                                        Look at You
# 48      0.973                              Azon de ma gnin kpevi
# 337     0.972  Let's Lovedance Tonight - Danny Krivit Re-edit...
# 1590    0.972                                   Jelly On A Plate
# 838     0.971  Let's Lovedance Tonight - Danny Krivit Re-edit...
# 497     0.968                               Mi Swing es Tropical
# 112     0.967                                 Please Mr. Postman
#
#                            artist
# 460                   Ida Engberg
# 912                   Fats Domino
# 1966                       Polina
# 207                 George McCrae
# 48    T. P. Orchestre Poly-Rythmo
# 337                   Gary's Gang
# ...

# %%
plt.figure(figsize=(12,7))
sns.barplot(x='valence', y='song_title', data=top_ten_valence_tracks, palette='viridis')
plt.title("Top 10 Tracks with the Most Valence")
plt.xlabel("Valence")
plt.ylabel("Song Title")
plt.show()
# Out:
# C:\Users\Sandra Kimiring\AppData\Local\Temp\ipykernel_35088\3282225653.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='valence', y='song_title', data=top_ten_valence_tracks, palette='viridis')

# %%
most_common_duration = df['duration_ms'].value_counts().head(5)  
most_common_duration
# Out:
# duration_ms
# 192000    5
# 243493    3
# 206013    3
# 228467    3
# 240000    3
# Name: count, dtype: int64

# %%
plt.figure(figsize=(12,7))
sns.barplot(x=most_common_duration.index, y=most_common_duration.values, palette='viridis')
plt.title("Most Common Durations")
plt.xlabel("Duration (ms)")
plt.ylabel("Frequency")
plt.show()
# Out:
# C:\Users\Sandra Kimiring\AppData\Local\Temp\ipykernel_35088\4257213361.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=most_common_duration.index, y=most_common_duration.values, palette='viridis')
